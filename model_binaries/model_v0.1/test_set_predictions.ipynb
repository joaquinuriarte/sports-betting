# %%
######## Find Optimal Decision Boundary Threshold for Models

# Loads model's weights
# Using validation dataset, find optimal threshold
# Test final accuracy on test dataset

# %% [markdown]
# Import All Required Modules

# %%
import sys

# Manually add the project root to sys.path
sys.path.append('/Users/joaquinuriarte/Documents/GitHub/sports-betting/')

# === STEP 0: Imports
print("# === STEP 0: Imports: Starting ...")
from modules.model_manager.trainer.trainer import Trainer
from modules.model_manager.predictor.predictor import Predictor
from modules.model_manager.factories.model_factory import ModelFactory
from modules.model_manager.helpers.configuration_loader import ConfigurationLoader as MMConfigLoader
from modules.model_manager.model_manager import ModelManager
print("# === STEP 0: Imports: Complete")
# Out:
# # === STEP 0: Imports: Starting ...
# 2025-01-23 10:07:13.180382: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# # === STEP 0: Imports: Complete

# %%
# === STEP 1: Dependency Instantiations And Global Variable Declarations
print("# === STEP 1: Dependency Instantiations And Global Variable Declarations: Starting ...")
## === MODEL MANAGER
yaml_path0 = '/Users/joaquinuriarte/Documents/GitHub/sports-betting/configs/model_v01/model_v01_000.yaml'
yaml_path1 = '/Users/joaquinuriarte/Documents/GitHub/sports-betting/configs/model_v01/model_v01_001.yaml'
yaml_path2 = '/Users/joaquinuriarte/Documents/GitHub/sports-betting/configs/model_v01/model_v01_002.yaml'

yaml_paths = [yaml_path0, yaml_path1]

checkpoint = '/Users/joaquinuriarte/Documents/GitHub/sports-betting/models'
trainer = Trainer(checkpoint)
predictor = Predictor()
model_factory = ModelFactory()
mm_configuration_loader = MMConfigLoader()
print("# === STEP 1: Dependency Instantiations And Global Variable Declarations: Complete")
# Out:
# # === STEP 1: Dependency Instantiations And Global Variable Declarations: Starting ...
# # === STEP 1: Dependency Instantiations And Global Variable Declarations: Complete

# %% [markdown]
# Load Val, and Test Datasets into Memory

# %%
import pickle
import os

# File path to load train, test, and val datasets
train_test_val_dataset_path = "/Users/joaquinuriarte/Documents/GitHub/sports-betting/processed_datasets/model_v01"


test_dataset_path = train_test_val_dataset_path + "/test.pkl"

with open(test_dataset_path, "rb") as f:
    test_dataset = pickle.load(f)
    print("Test dataset leaded to memory")
# Out:
# Test dataset leaded to memory

# %% [markdown]
# Load Models

# %%
## For all YAMLS, get their model's signatures
import yaml

yaml_path_list = [yaml_path2]
signatures = []

for yaml_file in yaml_path_list:
    with open(yaml_file, "r") as file:
        config_data = yaml.safe_load(file)

    # Save model signature 
    signatures.append(config_data.get("model", {}).get("model_signature"))

## Using model's signatures, get model's weights path
weights_paths =[]

for signature in signatures:
    base_path = '/Users/joaquinuriarte/Documents/GitHub/sports-betting/z-model_binaries/model_v0.1/models/'
    base_file_name = '/model_weights_'

    directory = base_path + signature
    file_name = base_file_name + signature + ".pth"

    final_file_path = directory + file_name

    weights_paths.append(final_file_path)

# %%
# === STEP 4: MODEL MANAGER
model_manager = ModelManager(trainer, predictor, model_factory, mm_configuration_loader)
models = model_manager.load_models([yaml_path2], weights_paths)
print("Models successfully loaded ")
# Out:
# Models successfully loaded

# %% [markdown]
# Predict on Test Set

# %%
predictions = []
for model in models:
    predictions.append(model.predict(test_dataset.examples, return_target_labels=True))

total_examples = 0
correct_predictions = 0

for prediction in predictions:
    for row in prediction.itertuples(index=False):
        total_examples += 1

        # Compare predictions and target labels for the current feature
        if (row.final_score_A > row.final_score_B and row.target_final_score_A > row.target_final_score_B) or \
        (row.final_score_A < row.final_score_B and row.target_final_score_A < row.target_final_score_B):
            correct_predictions += 1

    # Calculate accuracy
    accuracy = correct_predictions / total_examples
    print(f"Accuracy across all features on test dataset: {accuracy}")
# Out:
# Accuracy across all features on test dataset: 0.5871102960440137

# %%
total_examples = 0
correct_predictions = 0
correct_b_predictions = 0

for row in predictions[0].itertuples(index=False):
    print(row)
#     total_examples += 1
    
#     # Compare predictions and target labels for the current feature
#     if (row.final_score_A > row.final_score_B and row.target_final_score_A > row.target_final_score_B):
#         correct_predictions += 1
#     elif (row.final_score_A < row.final_score_B and row.target_final_score_A < row.target_final_score_B):
#         correct_predictions += 1
#         correct_b_predictions += 1  

# # Calculate accuracy
# accuracy = correct_predictions / total_examples
# percent_of_b_in_total_correct_pred = correct_b_predictions / correct_predictions
# print(f"Accuracy across all features on validation dataset: {accuracy} and percent_of_b_in_total_correct_pred: {percent_of_b_in_total_correct_pred}")
# Out:
# Pandas(final_score_A=106.05768585205078, final_score_B=106.35191345214844, target_final_score_A=108.0, target_final_score_B=115.0)
# Pandas(final_score_A=97.88880157470703, final_score_B=97.08341979980469, target_final_score_A=103.0, target_final_score_B=94.0)
# Pandas(final_score_A=103.83797454833984, final_score_B=99.23739624023438, target_final_score_A=108.0, target_final_score_B=105.0)
# Pandas(final_score_A=111.43476104736328, final_score_B=107.74172973632812, target_final_score_A=86.0, target_final_score_B=117.0)
# Pandas(final_score_A=109.81245422363281, final_score_B=108.40766906738281, target_final_score_A=123.0, target_final_score_B=109.0)
# Pandas(final_score_A=106.0184326171875, final_score_B=106.6052017211914, target_final_score_A=98.0, target_final_score_B=102.0)
# Pandas(final_score_A=98.35511779785156, final_score_B=95.48030853271484, target_final_score_A=111.0, target_final_score_B=100.0)
# Pandas(final_score_A=104.52734375, final_score_B=104.20361328125, target_final_score_A=110.0, target_final_score_B=118.0)
# Pandas(final_score_A=114.54914855957031, final_score_B=113.18059539794922, target_final_score_A=107.0, target_final_score_B=70.0)
# Pandas(final_score_A=98.31536865234375, final_score_B=95.97396850585938, target_final_score_A=100.0, target_final_score_B=106.0)
# Pandas(final_score_A=101.16436004638672, final_score_B=101.49703979492188, target_final_score_A=92.0, target_final_score_B=100.0)
# Pandas(final_score_A=97.00370788574219, final_score_B=92.21270751953125, target_final_score_A=107.0, target_final_score_B=87.0)
# Pandas(final_score_A=100.0116195678711, final_score_B=95.08596801757812, target_final_score_A=115.0, target_final_score_B=83.0)
# Pandas(final_score_A=113.48555755615234, final_score_B=114.1425552368164, target_final_score_A=126.0, target_final_score_B=102.0)
# Pandas(final_score_A=99.54151153564453, final_score_B=99.90142822265625, target_final_score_A=94.0, target_final_score_B=95.0)
# Pandas(final_score_A=103.9079360961914, final_score_B=103.5263671875, target_final_score_A=120.0, target_final_score_B=113.0)
# Pandas(final_score_A=108.31803894042969, final_score_B=102.43327331542969, target_final_score_A=129.0, target_final_score_B=98.0)
# Pandas(final_score_A=97.60173797607422, final_score_B=95.03678894042969, target_final_score_A=102.0, target_final_score_B=77.0)
# Pandas(final_score_A=100.75852966308594, final_score_B=98.34662628173828, target_final_score_A=98.0, target_final_score_B=114.0)
# Pandas(final_score_A=94.92694854736328, final_score_B=90.48187255859375, target_final_score_A=95.0, target_final_score_B=108.0)
# Pandas(final_score_A=96.08287811279297, final_score_B=91.98452758789062, target_final_score_A=74.0, target_final_score_B=81.0)
# Pandas(final_score_A=101.56890106201172, final_score_B=96.81970977783203, target_final_score_A=115.0, target_final_score_B=109.0)
# Pandas(final_score_A=103.93487548828125, final_score_B=103.85836791992188, target_final_score_A=104.0, target_final_score_B=101.0)
# Pandas(final_score_A=95.1287612915039, final_score_B=92.62734985351562, target_final_score_A=105.0, target_final_score_B=83.0)
# Pandas(final_score_A=108.83052825927734, final_score_B=109.13003540039062, target_final_score_A=104.0, target_final_score_B=119.0)
# Pandas(final_score_A=101.99085235595703, final_score_B=103.1795654296875, target_final_score_A=128.0, target_final_score_B=110.0)
# Pandas(final_score_A=99.91093444824219, final_score_B=95.04383850097656, target_final_score_A=136.0, target_final_score_B=100.0)
# Pandas(final_score_A=101.8577651977539, final_score_B=102.86219787597656, target_final_score_A=80.0, target_final_score_B=111.0)
# Pandas(final_score_A=100.50235748291016, final_score_B=96.37950897216797, target_final_score_A=86.0, target_final_score_B=98.0)
# Pandas(final_score_A=100.49673461914062, final_score_B=101.24606323242188, target_final_score_A=91.0, target_final_score_B=81.0)
# Pandas(final_score_A=102.44774627685547, final_score_B=100.98725891113281, target_final_score_A=115.0, target_final_score_B=107.0)
# Pandas(final_score_A=112.2065200805664, final_score_B=112.8525619506836, target_final_score_A=122.0, target_final_score_B=108.0)
# Pandas(final_score_A=98.641845703125, final_score_B=94.49716186523438, target_final_score_A=106.0, target_final_score_B=112.0)
# Pandas(final_score_A=105.11515045166016, final_score_B=104.41519927978516, target_final_score_A=107.0, target_final_score_B=118.0)
# Pandas(final_score_A=97.62405395507812, final_score_B=94.74098205566406, target_final_score_A=110.0, target_final_score_B=105.0)
# Pandas(final_score_A=102.81089782714844, final_score_B=102.84219360351562, target_final_score_A=89.0, target_final_score_B=106.0)
# Pandas(final_score_A=99.44476318359375, final_score_B=99.34568786621094, target_final_score_A=103.0, target_final_score_B=104.0)
# Pandas(final_score_A=95.65198516845703, final_score_B=95.60588073730469, target_final_score_A=109.0, target_final_score_B=94.0)
# Pandas(final_score_A=112.8320541381836, final_score_B=109.65744018554688, target_final_score_A=114.0, target_final_score_B=101.0)
# Pandas(final_score_A=98.19786834716797, final_score_B=98.35684204101562, target_final_score_A=98.0, target_final_score_B=100.0)
# Pandas(final_score_A=100.46964263916016, final_score_B=99.69511413574219, target_final_score_A=106.0, target_final_score_B=110.0)
# Pandas(final_score_A=104.38750457763672, final_score_B=100.77169799804688, target_final_score_A=117.0, target_final_score_B=119.0)
# Pandas(final_score_A=107.03423309326172, final_score_B=103.7602310180664, target_final_score_A=114.0, target_final_score_B=90.0)
# Pandas(final_score_A=109.6393051147461, final_score_B=109.094970703125, target_final_score_A=118.0, target_final_score_B=93.0)
# Pandas(final_score_A=97.64463806152344, final_score_B=96.12237548828125, target_final_score_A=85.0, target_final_score_B=90.0)
# Pandas(final_score_A=100.67320251464844, final_score_B=97.31245422363281, target_final_score_A=115.0, target_final_score_B=106.0)
# Pandas(final_score_A=103.85398864746094, final_score_B=103.95976257324219, target_final_score_A=107.0, target_final_score_B=120.0)
# Pandas(final_score_A=103.82953643798828, final_score_B=99.67678833007812, target_final_score_A=115.0, target_final_score_B=102.0)
# Pandas(final_score_A=105.26029205322266, final_score_B=103.03227233886719, target_final_score_A=109.0, target_final_score_B=110.0)
# Pandas(final_score_A=100.21640014648438, final_score_B=100.17646789550781, target_final_score_A=113.0, target_final_score_B=110.0)
# Pandas(final_score_A=104.10066986083984, final_score_B=101.57320404052734, target_final_score_A=110.0, target_final_score_B=92.0)
# Pandas(final_score_A=102.63741302490234, final_score_B=100.91639709472656, target_final_score_A=99.0, target_final_score_B=82.0)
# Pandas(final_score_A=106.70289611816406, final_score_B=107.53535461425781, target_final_score_A=91.0, target_final_score_B=104.0)
# Pandas(final_score_A=112.57575225830078, final_score_B=112.10255432128906, target_final_score_A=107.0, target_final_score_B=96.0)
# Pandas(final_score_A=105.80070495605469, final_score_B=106.53913879394531, target_final_score_A=106.0, target_final_score_B=130.0)
# Pandas(final_score_A=109.23601531982422, final_score_B=108.51023864746094, target_final_score_A=125.0, target_final_score_B=112.0)
# Pandas(final_score_A=108.31864166259766, final_score_B=106.2795639038086, target_final_score_A=117.0, target_final_score_B=116.0)
# Pandas(final_score_A=105.68842315673828, final_score_B=103.90309143066406, target_final_score_A=76.0, target_final_score_B=97.0)
# Pandas(final_score_A=106.4372329711914, final_score_B=102.47683715820312, target_final_score_A=101.0, target_final_score_B=99.0)
# Pandas(final_score_A=97.39080810546875, final_score_B=93.5789566040039, target_final_score_A=101.0, target_final_score_B=94.0)
# Pandas(final_score_A=109.88383483886719, final_score_B=109.04615783691406, target_final_score_A=96.0, target_final_score_B=88.0)
# Pandas(final_score_A=106.98897552490234, final_score_B=103.53636169433594, target_final_score_A=103.0, target_final_score_B=124.0)
# Pandas(final_score_A=103.95846557617188, final_score_B=103.10035705566406, target_final_score_A=104.0, target_final_score_B=88.0)
# Pandas(final_score_A=108.59436798095703, final_score_B=110.11598205566406, target_final_score_A=101.0, target_final_score_B=109.0)
# Pandas(final_score_A=95.55221557617188, final_score_B=96.02590942382812, target_final_score_A=94.0, target_final_score_B=87.0)
# Pandas(final_score_A=105.31855773925781, final_score_B=105.92811584472656, target_final_score_A=101.0, target_final_score_B=117.0)
# Pandas(final_score_A=101.40811920166016, final_score_B=99.76848602294922, target_final_score_A=103.0, target_final_score_B=110.0)
# Pandas(final_score_A=106.21796417236328, final_score_B=100.58674621582031, target_final_score_A=105.0, target_final_score_B=115.0)
# Pandas(final_score_A=114.4476318359375, final_score_B=114.96971130371094, target_final_score_A=109.0, target_final_score_B=102.0)
# Pandas(final_score_A=98.34355926513672, final_score_B=98.34832763671875, target_final_score_A=98.0, target_final_score_B=117.0)
# Pandas(final_score_A=115.45378875732422, final_score_B=115.33747863769531, target_final_score_A=112.0, target_final_score_B=98.0)
# Pandas(final_score_A=106.59984588623047, final_score_B=106.28199768066406, target_final_score_A=111.0, target_final_score_B=100.0)
# Pandas(final_score_A=97.06317901611328, final_score_B=95.83755493164062, target_final_score_A=82.0, target_final_score_B=103.0)
# Pandas(final_score_A=111.9135971069336, final_score_B=106.91293334960938, target_final_score_A=121.0, target_final_score_B=125.0)
# Pandas(final_score_A=109.13794708251953, final_score_B=107.73835754394531, target_final_score_A=126.0, target_final_score_B=98.0)
# Pandas(final_score_A=97.21929168701172, final_score_B=95.30302429199219, target_final_score_A=86.0, target_final_score_B=103.0)
# Pandas(final_score_A=100.60487365722656, final_score_B=96.42510986328125, target_final_score_A=104.0, target_final_score_B=100.0)
# Pandas(final_score_A=103.86983489990234, final_score_B=104.05029296875, target_final_score_A=106.0, target_final_score_B=98.0)
# Pandas(final_score_A=106.97134399414062, final_score_B=106.81742858886719, target_final_score_A=123.0, target_final_score_B=112.0)
# Pandas(final_score_A=110.11096954345703, final_score_B=109.88883972167969, target_final_score_A=127.0, target_final_score_B=114.0)
# Pandas(final_score_A=97.01251983642578, final_score_B=97.81575012207031, target_final_score_A=111.0, target_final_score_B=115.0)
# Pandas(final_score_A=101.81892395019531, final_score_B=100.89022827148438, target_final_score_A=112.0, target_final_score_B=103.0)
# Pandas(final_score_A=103.25616455078125, final_score_B=103.34138488769531, target_final_score_A=100.0, target_final_score_B=112.0)
# Pandas(final_score_A=107.1274185180664, final_score_B=107.51145935058594, target_final_score_A=96.0, target_final_score_B=100.0)
# Pandas(final_score_A=105.36161041259766, final_score_B=103.33004760742188, target_final_score_A=95.0, target_final_score_B=111.0)
# Pandas(final_score_A=105.57747650146484, final_score_B=101.52400970458984, target_final_score_A=95.0, target_final_score_B=88.0)
# Pandas(final_score_A=105.73794555664062, final_score_B=105.15525817871094, target_final_score_A=100.0, target_final_score_B=106.0)
# Pandas(final_score_A=97.86725616455078, final_score_B=97.93479919433594, target_final_score_A=104.0, target_final_score_B=91.0)
# Pandas(final_score_A=98.64620208740234, final_score_B=98.39545440673828, target_final_score_A=99.0, target_final_score_B=91.0)
# Pandas(final_score_A=99.30717468261719, final_score_B=96.68949127197266, target_final_score_A=72.0, target_final_score_B=75.0)
# Pandas(final_score_A=112.77371215820312, final_score_B=112.4805908203125, target_final_score_A=126.0, target_final_score_B=98.0)
# Pandas(final_score_A=103.42452239990234, final_score_B=102.63230895996094, target_final_score_A=89.0, target_final_score_B=93.0)
# Pandas(final_score_A=108.49909973144531, final_score_B=108.33555603027344, target_final_score_A=104.0, target_final_score_B=88.0)
# Pandas(final_score_A=99.65939331054688, final_score_B=94.729736328125, target_final_score_A=93.0, target_final_score_B=70.0)
# Pandas(final_score_A=101.60433959960938, final_score_B=99.39747619628906, target_final_score_A=103.0, target_final_score_B=89.0)
# Pandas(final_score_A=104.82662200927734, final_score_B=104.68801879882812, target_final_score_A=121.0, target_final_score_B=104.0)
# Pandas(final_score_A=103.33716583251953, final_score_B=103.39183044433594, target_final_score_A=94.0, target_final_score_B=112.0)
# Pandas(final_score_A=99.87922668457031, final_score_B=97.05500793457031, target_final_score_A=82.0, target_final_score_B=81.0)
# Pandas(final_score_A=98.49522399902344, final_score_B=98.42732238769531, target_final_score_A=98.0, target_final_score_B=90.0)
# Pandas(final_score_A=100.86979675292969, final_score_B=101.01065063476562, target_final_score_A=118.0, target_final_score_B=111.0)
# Pandas(final_score_A=100.50817108154297, final_score_B=96.9644775390625, target_final_score_A=108.0, target_final_score_B=99.0)
# Pandas(final_score_A=106.18453979492188, final_score_B=106.47613525390625, target_final_score_A=111.0, target_final_score_B=106.0)
# Pandas(final_score_A=104.52584075927734, final_score_B=102.93359375, target_final_score_A=89.0, target_final_score_B=77.0)
# Pandas(final_score_A=99.77730560302734, final_score_B=96.556884765625, target_final_score_A=99.0, target_final_score_B=90.0)
# Pandas(final_score_A=96.7050552368164, final_score_B=94.5120849609375, target_final_score_A=103.0, target_final_score_B=89.0)
# Pandas(final_score_A=97.53071594238281, final_score_B=97.03115844726562, target_final_score_A=85.0, target_final_score_B=110.0)
# Pandas(final_score_A=108.4239730834961, final_score_B=108.80996704101562, target_final_score_A=124.0, target_final_score_B=104.0)
# Pandas(final_score_A=106.27621459960938, final_score_B=101.71800994873047, target_final_score_A=104.0, target_final_score_B=109.0)
# Pandas(final_score_A=94.81365966796875, final_score_B=91.66865539550781, target_final_score_A=90.0, target_final_score_B=95.0)
# Pandas(final_score_A=102.7555160522461, final_score_B=97.40841674804688, target_final_score_A=113.0, target_final_score_B=104.0)
# Pandas(final_score_A=97.92193603515625, final_score_B=98.21623992919922, target_final_score_A=99.0, target_final_score_B=87.0)
# Pandas(final_score_A=110.38390350341797, final_score_B=105.86885833740234, target_final_score_A=106.0, target_final_score_B=114.0)
# Pandas(final_score_A=99.26481628417969, final_score_B=98.71788787841797, target_final_score_A=92.0, target_final_score_B=101.0)
# Pandas(final_score_A=103.33356475830078, final_score_B=101.5808334350586, target_final_score_A=90.0, target_final_score_B=88.0)
# Pandas(final_score_A=95.34957122802734, final_score_B=90.98736572265625, target_final_score_A=92.0, target_final_score_B=81.0)
# Pandas(final_score_A=102.17525482177734, final_score_B=100.36604309082031, target_final_score_A=98.0, target_final_score_B=89.0)
# Pandas(final_score_A=103.58528900146484, final_score_B=98.32760620117188, target_final_score_A=131.0, target_final_score_B=119.0)
# Pandas(final_score_A=103.87287139892578, final_score_B=101.61366271972656, target_final_score_A=96.0, target_final_score_B=94.0)
# Pandas(final_score_A=101.95293426513672, final_score_B=98.02002716064453, target_final_score_A=87.0, target_final_score_B=76.0)
# Pandas(final_score_A=109.88263702392578, final_score_B=105.06097412109375, target_final_score_A=111.0, target_final_score_B=80.0)
# Pandas(final_score_A=104.2208251953125, final_score_B=103.95972442626953, target_final_score_A=99.0, target_final_score_B=84.0)
# Pandas(final_score_A=99.99783325195312, final_score_B=97.9471206665039, target_final_score_A=104.0, target_final_score_B=96.0)
# Pandas(final_score_A=105.57064056396484, final_score_B=103.7633056640625, target_final_score_A=109.0, target_final_score_B=117.0)
# Pandas(final_score_A=105.24121856689453, final_score_B=106.53831481933594, target_final_score_A=97.0, target_final_score_B=112.0)
# Pandas(final_score_A=97.26985931396484, final_score_B=91.69482421875, target_final_score_A=103.0, target_final_score_B=110.0)
# Pandas(final_score_A=97.89630889892578, final_score_B=93.33084106445312, target_final_score_A=105.0, target_final_score_B=90.0)
# Pandas(final_score_A=97.3274154663086, final_score_B=95.67259216308594, target_final_score_A=86.0, target_final_score_B=103.0)
# Pandas(final_score_A=104.01038360595703, final_score_B=101.362548828125, target_final_score_A=107.0, target_final_score_B=92.0)
# Pandas(final_score_A=97.99153137207031, final_score_B=96.74064636230469, target_final_score_A=95.0, target_final_score_B=105.0)
# Pandas(final_score_A=95.6857681274414, final_score_B=95.68081665039062, target_final_score_A=96.0, target_final_score_B=89.0)
# Pandas(final_score_A=93.4032974243164, final_score_B=88.04084777832031, target_final_score_A=103.0, target_final_score_B=102.0)
# Pandas(final_score_A=105.74197387695312, final_score_B=102.1631088256836, target_final_score_A=117.0, target_final_score_B=104.0)
# Pandas(final_score_A=98.96614837646484, final_score_B=93.97578430175781, target_final_score_A=94.0, target_final_score_B=95.0)
# Pandas(final_score_A=103.60076141357422, final_score_B=104.39035034179688, target_final_score_A=107.0, target_final_score_B=112.0)
# Pandas(final_score_A=100.73357391357422, final_score_B=95.72786712646484, target_final_score_A=100.0, target_final_score_B=79.0)
# Pandas(final_score_A=107.32011413574219, final_score_B=107.44802856445312, target_final_score_A=100.0, target_final_score_B=117.0)
# Pandas(final_score_A=107.10755157470703, final_score_B=107.51832580566406, target_final_score_A=108.0, target_final_score_B=78.0)
# Pandas(final_score_A=100.90420532226562, final_score_B=96.30656433105469, target_final_score_A=122.0, target_final_score_B=93.0)
# Pandas(final_score_A=100.88228607177734, final_score_B=99.50106811523438, target_final_score_A=104.0, target_final_score_B=101.0)
# Pandas(final_score_A=104.99478149414062, final_score_B=105.28038787841797, target_final_score_A=95.0, target_final_score_B=89.0)
# Pandas(final_score_A=97.7513656616211, final_score_B=94.93013000488281, target_final_score_A=88.0, target_final_score_B=83.0)
# Pandas(final_score_A=104.97384643554688, final_score_B=105.58895874023438, target_final_score_A=108.0, target_final_score_B=104.0)
# Pandas(final_score_A=101.57511138916016, final_score_B=96.88066101074219, target_final_score_A=121.0, target_final_score_B=98.0)
# Pandas(final_score_A=101.9135971069336, final_score_B=98.84222412109375, target_final_score_A=108.0, target_final_score_B=86.0)
# Pandas(final_score_A=94.66585540771484, final_score_B=91.99238586425781, target_final_score_A=94.0, target_final_score_B=74.0)
# Pandas(final_score_A=94.82596588134766, final_score_B=91.72863006591797, target_final_score_A=83.0, target_final_score_B=75.0)
# Pandas(final_score_A=104.42866516113281, final_score_B=103.84197998046875, target_final_score_A=100.0, target_final_score_B=102.0)
# Pandas(final_score_A=97.20043182373047, final_score_B=97.018310546875, target_final_score_A=67.0, target_final_score_B=71.0)
# Pandas(final_score_A=103.48741912841797, final_score_B=103.25320434570312, target_final_score_A=90.0, target_final_score_B=93.0)
# Pandas(final_score_A=104.43707275390625, final_score_B=102.47280883789062, target_final_score_A=112.0, target_final_score_B=80.0)
# Pandas(final_score_A=99.45257568359375, final_score_B=97.25994873046875, target_final_score_A=106.0, target_final_score_B=84.0)
# Pandas(final_score_A=99.02227020263672, final_score_B=95.21564483642578, target_final_score_A=99.0, target_final_score_B=85.0)
# Pandas(final_score_A=103.7159423828125, final_score_B=98.68472290039062, target_final_score_A=109.0, target_final_score_B=97.0)
# Pandas(final_score_A=99.96812438964844, final_score_B=98.59076690673828, target_final_score_A=93.0, target_final_score_B=92.0)
# Pandas(final_score_A=101.38045501708984, final_score_B=95.63895416259766, target_final_score_A=109.0, target_final_score_B=108.0)
# Pandas(final_score_A=101.54749298095703, final_score_B=101.12135314941406, target_final_score_A=99.0, target_final_score_B=86.0)
# Pandas(final_score_A=102.66039276123047, final_score_B=101.68241119384766, target_final_score_A=112.0, target_final_score_B=116.0)
# Pandas(final_score_A=108.14503479003906, final_score_B=106.95504760742188, target_final_score_A=104.0, target_final_score_B=113.0)
# Pandas(final_score_A=102.40270233154297, final_score_B=101.48414611816406, target_final_score_A=92.0, target_final_score_B=81.0)
# Pandas(final_score_A=97.5639419555664, final_score_B=92.13868713378906, target_final_score_A=112.0, target_final_score_B=88.0)
# Pandas(final_score_A=111.2482681274414, final_score_B=105.30793762207031, target_final_score_A=109.0, target_final_score_B=104.0)
# Pandas(final_score_A=97.60641479492188, final_score_B=95.82073211669922, target_final_score_A=89.0, target_final_score_B=95.0)
# Pandas(final_score_A=103.95443725585938, final_score_B=103.71092987060547, target_final_score_A=99.0, target_final_score_B=85.0)
# Pandas(final_score_A=114.5724868774414, final_score_B=110.48036193847656, target_final_score_A=121.0, target_final_score_B=98.0)
# Pandas(final_score_A=98.81837463378906, final_score_B=94.59295654296875, target_final_score_A=88.0, target_final_score_B=100.0)
# Pandas(final_score_A=102.84781646728516, final_score_B=103.12248229980469, target_final_score_A=106.0, target_final_score_B=113.0)
# Pandas(final_score_A=109.16067504882812, final_score_B=110.77124786376953, target_final_score_A=133.0, target_final_score_B=105.0)
# Pandas(final_score_A=96.94837188720703, final_score_B=96.36366271972656, target_final_score_A=104.0, target_final_score_B=97.0)
# Pandas(final_score_A=100.83460998535156, final_score_B=97.69050598144531, target_final_score_A=121.0, target_final_score_B=102.0)
# Pandas(final_score_A=106.47357177734375, final_score_B=103.18733215332031, target_final_score_A=115.0, target_final_score_B=109.0)
# Pandas(final_score_A=102.59513092041016, final_score_B=101.68183898925781, target_final_score_A=103.0, target_final_score_B=94.0)
# Pandas(final_score_A=102.23138427734375, final_score_B=100.82371520996094, target_final_score_A=114.0, target_final_score_B=119.0)
# Pandas(final_score_A=96.19712829589844, final_score_B=94.71763610839844, target_final_score_A=102.0, target_final_score_B=98.0)
# Pandas(final_score_A=100.26858520507812, final_score_B=95.62287139892578, target_final_score_A=83.0, target_final_score_B=85.0)
# Pandas(final_score_A=103.3354721069336, final_score_B=102.2916259765625, target_final_score_A=93.0, target_final_score_B=87.0)
# Pandas(final_score_A=103.46050262451172, final_score_B=101.00847625732422, target_final_score_A=104.0, target_final_score_B=106.0)
# Pandas(final_score_A=110.00592041015625, final_score_B=106.10673522949219, target_final_score_A=115.0, target_final_score_B=133.0)
# Pandas(final_score_A=109.35205841064453, final_score_B=109.54216766357422, target_final_score_A=112.0, target_final_score_B=80.0)
# Pandas(final_score_A=106.07415008544922, final_score_B=106.57695007324219, target_final_score_A=140.0, target_final_score_B=128.0)
# Pandas(final_score_A=103.7424087524414, final_score_B=103.54072570800781, target_final_score_A=113.0, target_final_score_B=105.0)
# Pandas(final_score_A=99.774169921875, final_score_B=98.53277587890625, target_final_score_A=88.0, target_final_score_B=82.0)
# Pandas(final_score_A=105.6661148071289, final_score_B=105.30062866210938, target_final_score_A=84.0, target_final_score_B=83.0)
# Pandas(final_score_A=98.92086791992188, final_score_B=97.46672058105469, target_final_score_A=107.0, target_final_score_B=105.0)
# Pandas(final_score_A=97.04536437988281, final_score_B=94.17454528808594, target_final_score_A=95.0, target_final_score_B=82.0)
# Pandas(final_score_A=99.9672622680664, final_score_B=100.23255920410156, target_final_score_A=94.0, target_final_score_B=96.0)
# Pandas(final_score_A=103.5834732055664, final_score_B=98.36995697021484, target_final_score_A=101.0, target_final_score_B=105.0)
# Pandas(final_score_A=100.51160430908203, final_score_B=96.02336120605469, target_final_score_A=102.0, target_final_score_B=93.0)
# Pandas(final_score_A=98.90283203125, final_score_B=98.3948974609375, target_final_score_A=108.0, target_final_score_B=116.0)
# Pandas(final_score_A=102.3777084350586, final_score_B=102.66443634033203, target_final_score_A=118.0, target_final_score_B=113.0)
# Pandas(final_score_A=98.59671783447266, final_score_B=98.80859375, target_final_score_A=88.0, target_final_score_B=110.0)
# Pandas(final_score_A=99.87374114990234, final_score_B=97.34280395507812, target_final_score_A=93.0, target_final_score_B=86.0)
# Pandas(final_score_A=100.41972351074219, final_score_B=95.85436248779297, target_final_score_A=95.0, target_final_score_B=73.0)
# Pandas(final_score_A=102.6145248413086, final_score_B=101.12032318115234, target_final_score_A=95.0, target_final_score_B=110.0)
# Pandas(final_score_A=92.62911224365234, final_score_B=88.30372619628906, target_final_score_A=93.0, target_final_score_B=86.0)
# Pandas(final_score_A=95.20732879638672, final_score_B=95.73944091796875, target_final_score_A=114.0, target_final_score_B=71.0)
# Pandas(final_score_A=96.41475677490234, final_score_B=95.4564208984375, target_final_score_A=124.0, target_final_score_B=119.0)
# Pandas(final_score_A=103.1205825805664, final_score_B=100.41188049316406, target_final_score_A=98.0, target_final_score_B=83.0)
# Pandas(final_score_A=106.27062225341797, final_score_B=101.50054931640625, target_final_score_A=93.0, target_final_score_B=112.0)
# Pandas(final_score_A=99.09757995605469, final_score_B=97.64643096923828, target_final_score_A=104.0, target_final_score_B=90.0)
# Pandas(final_score_A=98.92499542236328, final_score_B=93.73005676269531, target_final_score_A=116.0, target_final_score_B=109.0)
# Pandas(final_score_A=105.71968841552734, final_score_B=103.98212432861328, target_final_score_A=108.0, target_final_score_B=105.0)
# Pandas(final_score_A=100.4413070678711, final_score_B=99.82791137695312, target_final_score_A=120.0, target_final_score_B=93.0)
# Pandas(final_score_A=104.53968048095703, final_score_B=104.88507080078125, target_final_score_A=115.0, target_final_score_B=122.0)
# Pandas(final_score_A=99.43067932128906, final_score_B=96.29077911376953, target_final_score_A=99.0, target_final_score_B=69.0)
# Pandas(final_score_A=108.7516860961914, final_score_B=109.15179443359375, target_final_score_A=123.0, target_final_score_B=98.0)
# Pandas(final_score_A=98.31244659423828, final_score_B=95.77433776855469, target_final_score_A=118.0, target_final_score_B=105.0)
# Pandas(final_score_A=94.74418640136719, final_score_B=94.42133331298828, target_final_score_A=86.0, target_final_score_B=74.0)
# Pandas(final_score_A=103.29317474365234, final_score_B=98.81201171875, target_final_score_A=106.0, target_final_score_B=99.0)
# Pandas(final_score_A=104.99925994873047, final_score_B=101.96247100830078, target_final_score_A=111.0, target_final_score_B=103.0)
# Pandas(final_score_A=105.09415435791016, final_score_B=105.46282196044922, target_final_score_A=102.0, target_final_score_B=98.0)
# Pandas(final_score_A=102.8212661743164, final_score_B=102.59549713134766, target_final_score_A=87.0, target_final_score_B=93.0)
# Pandas(final_score_A=97.55985260009766, final_score_B=95.7674560546875, target_final_score_A=102.0, target_final_score_B=88.0)
# Pandas(final_score_A=97.7883529663086, final_score_B=95.25511169433594, target_final_score_A=89.0, target_final_score_B=93.0)
# Pandas(final_score_A=99.32197570800781, final_score_B=96.26107025146484, target_final_score_A=100.0, target_final_score_B=93.0)
# Pandas(final_score_A=104.7277603149414, final_score_B=105.77735900878906, target_final_score_A=113.0, target_final_score_B=110.0)
# Pandas(final_score_A=97.38689422607422, final_score_B=93.36393737792969, target_final_score_A=112.0, target_final_score_B=97.0)
# Pandas(final_score_A=100.21217346191406, final_score_B=100.30545043945312, target_final_score_A=90.0, target_final_score_B=87.0)
# Pandas(final_score_A=108.89949798583984, final_score_B=105.76296997070312, target_final_score_A=108.0, target_final_score_B=109.0)
# Pandas(final_score_A=106.22450256347656, final_score_B=104.03717041015625, target_final_score_A=102.0, target_final_score_B=96.0)
# Pandas(final_score_A=122.72638702392578, final_score_B=122.10382843017578, target_final_score_A=125.0, target_final_score_B=119.0)
# Pandas(final_score_A=95.76577758789062, final_score_B=96.08391571044922, target_final_score_A=101.0, target_final_score_B=77.0)
# Pandas(final_score_A=107.5558090209961, final_score_B=101.97761535644531, target_final_score_A=98.0, target_final_score_B=113.0)
# Pandas(final_score_A=97.4722900390625, final_score_B=94.22535705566406, target_final_score_A=98.0, target_final_score_B=85.0)
# Pandas(final_score_A=93.87812042236328, final_score_B=92.07669830322266, target_final_score_A=77.0, target_final_score_B=85.0)
# Pandas(final_score_A=99.73102569580078, final_score_B=95.30792999267578, target_final_score_A=97.0, target_final_score_B=70.0)
# Pandas(final_score_A=105.8125228881836, final_score_B=103.16983032226562, target_final_score_A=94.0, target_final_score_B=97.0)
# Pandas(final_score_A=104.74459838867188, final_score_B=103.4210433959961, target_final_score_A=99.0, target_final_score_B=112.0)
# Pandas(final_score_A=99.70722198486328, final_score_B=95.06986999511719, target_final_score_A=102.0, target_final_score_B=99.0)
# Pandas(final_score_A=101.4510726928711, final_score_B=98.34246063232422, target_final_score_A=102.0, target_final_score_B=92.0)
# Pandas(final_score_A=109.6203842163086, final_score_B=105.7545166015625, target_final_score_A=116.0, target_final_score_B=98.0)
# Pandas(final_score_A=105.47579193115234, final_score_B=100.64697265625, target_final_score_A=102.0, target_final_score_B=97.0)
# Pandas(final_score_A=99.25725555419922, final_score_B=98.08153533935547, target_final_score_A=96.0, target_final_score_B=101.0)
# Pandas(final_score_A=102.94683837890625, final_score_B=101.23500061035156, target_final_score_A=102.0, target_final_score_B=100.0)
# Pandas(final_score_A=96.30440521240234, final_score_B=92.0263442993164, target_final_score_A=98.0, target_final_score_B=91.0)
# Pandas(final_score_A=97.595703125, final_score_B=93.34463500976562, target_final_score_A=104.0, target_final_score_B=88.0)
# Pandas(final_score_A=99.51512908935547, final_score_B=96.87596893310547, target_final_score_A=87.0, target_final_score_B=95.0)
# Pandas(final_score_A=97.42334747314453, final_score_B=96.63487243652344, target_final_score_A=90.0, target_final_score_B=84.0)
# Pandas(final_score_A=109.19959259033203, final_score_B=104.35589599609375, target_final_score_A=108.0, target_final_score_B=113.0)
# Pandas(final_score_A=98.88581085205078, final_score_B=93.02926635742188, target_final_score_A=118.0, target_final_score_B=103.0)
# Pandas(final_score_A=99.91429138183594, final_score_B=98.39457702636719, target_final_score_A=88.0, target_final_score_B=76.0)
# Pandas(final_score_A=104.50626373291016, final_score_B=104.79879760742188, target_final_score_A=99.0, target_final_score_B=111.0)
# Pandas(final_score_A=97.6648941040039, final_score_B=95.41246032714844, target_final_score_A=110.0, target_final_score_B=105.0)
# Pandas(final_score_A=100.64167022705078, final_score_B=96.08657836914062, target_final_score_A=106.0, target_final_score_B=99.0)
# Pandas(final_score_A=102.83057403564453, final_score_B=100.35458374023438, target_final_score_A=118.0, target_final_score_B=125.0)
# Pandas(final_score_A=101.79443359375, final_score_B=102.36351013183594, target_final_score_A=86.0, target_final_score_B=98.0)
# Pandas(final_score_A=101.67090606689453, final_score_B=97.49674987792969, target_final_score_A=115.0, target_final_score_B=121.0)
# Pandas(final_score_A=108.37744903564453, final_score_B=108.71754455566406, target_final_score_A=117.0, target_final_score_B=108.0)
# Pandas(final_score_A=111.25019073486328, final_score_B=110.75911712646484, target_final_score_A=136.0, target_final_score_B=140.0)
# Pandas(final_score_A=104.3736801147461, final_score_B=102.67198181152344, target_final_score_A=89.0, target_final_score_B=107.0)
# Pandas(final_score_A=105.46175384521484, final_score_B=101.87464904785156, target_final_score_A=103.0, target_final_score_B=74.0)
# Pandas(final_score_A=98.45240783691406, final_score_B=93.46453857421875, target_final_score_A=104.0, target_final_score_B=98.0)
# Pandas(final_score_A=103.41658782958984, final_score_B=102.26493072509766, target_final_score_A=98.0, target_final_score_B=107.0)
# Pandas(final_score_A=100.96711730957031, final_score_B=100.30802917480469, target_final_score_A=125.0, target_final_score_B=120.0)
# Pandas(final_score_A=113.58511352539062, final_score_B=106.95022583007812, target_final_score_A=121.0, target_final_score_B=113.0)
# Pandas(final_score_A=108.1977767944336, final_score_B=103.29425048828125, target_final_score_A=104.0, target_final_score_B=91.0)
# Pandas(final_score_A=105.1253890991211, final_score_B=104.07709503173828, target_final_score_A=107.0, target_final_score_B=121.0)
# Pandas(final_score_A=108.97211456298828, final_score_B=109.4150161743164, target_final_score_A=113.0, target_final_score_B=104.0)
# Pandas(final_score_A=102.40423583984375, final_score_B=102.66633605957031, target_final_score_A=99.0, target_final_score_B=93.0)
# Pandas(final_score_A=121.76331329345703, final_score_B=119.03089904785156, target_final_score_A=116.0, target_final_score_B=137.0)
# Pandas(final_score_A=101.86637115478516, final_score_B=101.3932113647461, target_final_score_A=123.0, target_final_score_B=112.0)
# Pandas(final_score_A=100.96686553955078, final_score_B=100.70526123046875, target_final_score_A=105.0, target_final_score_B=99.0)
# Pandas(final_score_A=97.43233489990234, final_score_B=95.60293579101562, target_final_score_A=84.0, target_final_score_B=95.0)
# Pandas(final_score_A=105.90802764892578, final_score_B=105.63032531738281, target_final_score_A=81.0, target_final_score_B=114.0)
# Pandas(final_score_A=94.3729476928711, final_score_B=89.49842834472656, target_final_score_A=103.0, target_final_score_B=101.0)
# Pandas(final_score_A=98.08477020263672, final_score_B=93.63286590576172, target_final_score_A=91.0, target_final_score_B=109.0)
# Pandas(final_score_A=98.14366149902344, final_score_B=98.13470458984375, target_final_score_A=108.0, target_final_score_B=100.0)
# Pandas(final_score_A=96.4017333984375, final_score_B=95.868896484375, target_final_score_A=89.0, target_final_score_B=93.0)
# Pandas(final_score_A=105.84596252441406, final_score_B=104.55947875976562, target_final_score_A=100.0, target_final_score_B=110.0)
# Pandas(final_score_A=98.49115753173828, final_score_B=98.5888671875, target_final_score_A=90.0, target_final_score_B=89.0)
# Pandas(final_score_A=105.38682556152344, final_score_B=104.96002197265625, target_final_score_A=96.0, target_final_score_B=97.0)
# Pandas(final_score_A=106.09078216552734, final_score_B=105.80433654785156, target_final_score_A=118.0, target_final_score_B=111.0)
# Pandas(final_score_A=100.99225616455078, final_score_B=99.92271423339844, target_final_score_A=104.0, target_final_score_B=99.0)
# Pandas(final_score_A=101.2925796508789, final_score_B=97.87652587890625, target_final_score_A=89.0, target_final_score_B=74.0)
# Pandas(final_score_A=102.8936538696289, final_score_B=99.34930419921875, target_final_score_A=119.0, target_final_score_B=117.0)
# Pandas(final_score_A=113.82781219482422, final_score_B=114.29586791992188, target_final_score_A=94.0, target_final_score_B=109.0)
# Pandas(final_score_A=97.759033203125, final_score_B=96.22838592529297, target_final_score_A=133.0, target_final_score_B=99.0)
# Pandas(final_score_A=108.57656860351562, final_score_B=108.28113555908203, target_final_score_A=97.0, target_final_score_B=104.0)
# Pandas(final_score_A=110.91861724853516, final_score_B=110.94852447509766, target_final_score_A=87.0, target_final_score_B=93.0)
# Pandas(final_score_A=97.771728515625, final_score_B=94.85308837890625, target_final_score_A=86.0, target_final_score_B=77.0)
# Pandas(final_score_A=92.75624084472656, final_score_B=89.41881561279297, target_final_score_A=74.0, target_final_score_B=78.0)
# Pandas(final_score_A=94.16702270507812, final_score_B=92.38372802734375, target_final_score_A=88.0, target_final_score_B=105.0)
# Pandas(final_score_A=104.67817687988281, final_score_B=104.8428726196289, target_final_score_A=92.0, target_final_score_B=105.0)
# Pandas(final_score_A=100.24140930175781, final_score_B=99.08309936523438, target_final_score_A=96.0, target_final_score_B=83.0)
# Pandas(final_score_A=102.9084701538086, final_score_B=101.62913513183594, target_final_score_A=117.0, target_final_score_B=100.0)
# Pandas(final_score_A=101.76705169677734, final_score_B=102.28091430664062, target_final_score_A=111.0, target_final_score_B=101.0)
# Pandas(final_score_A=102.3616943359375, final_score_B=97.04240417480469, target_final_score_A=87.0, target_final_score_B=98.0)
# Pandas(final_score_A=98.5757827758789, final_score_B=95.62469482421875, target_final_score_A=101.0, target_final_score_B=96.0)
# Pandas(final_score_A=97.85083770751953, final_score_B=95.1328125, target_final_score_A=100.0, target_final_score_B=82.0)
# Pandas(final_score_A=100.36609649658203, final_score_B=100.07118225097656, target_final_score_A=118.0, target_final_score_B=120.0)
# Pandas(final_score_A=101.96440887451172, final_score_B=96.69184112548828, target_final_score_A=103.0, target_final_score_B=116.0)
# Pandas(final_score_A=95.28585052490234, final_score_B=92.56929779052734, target_final_score_A=95.0, target_final_score_B=87.0)
# Pandas(final_score_A=101.92884063720703, final_score_B=97.18521118164062, target_final_score_A=84.0, target_final_score_B=77.0)
# Pandas(final_score_A=97.6739273071289, final_score_B=92.5309829711914, target_final_score_A=107.0, target_final_score_B=88.0)
# Pandas(final_score_A=92.65679168701172, final_score_B=87.35843658447266, target_final_score_A=99.0, target_final_score_B=106.0)
# Pandas(final_score_A=102.81620788574219, final_score_B=102.41582489013672, target_final_score_A=95.0, target_final_score_B=101.0)
# Pandas(final_score_A=99.57577514648438, final_score_B=99.56615447998047, target_final_score_A=116.0, target_final_score_B=101.0)
# Pandas(final_score_A=104.52916717529297, final_score_B=100.09762573242188, target_final_score_A=122.0, target_final_score_B=102.0)
# Pandas(final_score_A=95.87776184082031, final_score_B=90.53929901123047, target_final_score_A=94.0, target_final_score_B=87.0)
# Pandas(final_score_A=110.46692657470703, final_score_B=111.48588562011719, target_final_score_A=116.0, target_final_score_B=86.0)
# Pandas(final_score_A=98.89861297607422, final_score_B=93.99916076660156, target_final_score_A=89.0, target_final_score_B=90.0)
# Pandas(final_score_A=100.48218536376953, final_score_B=100.24900817871094, target_final_score_A=109.0, target_final_score_B=120.0)
# Pandas(final_score_A=109.56037139892578, final_score_B=109.37126159667969, target_final_score_A=84.0, target_final_score_B=74.0)
# Pandas(final_score_A=104.53850555419922, final_score_B=104.98719024658203, target_final_score_A=81.0, target_final_score_B=97.0)
# Pandas(final_score_A=99.7596206665039, final_score_B=99.58302307128906, target_final_score_A=95.0, target_final_score_B=93.0)
# Pandas(final_score_A=107.41217803955078, final_score_B=104.38812255859375, target_final_score_A=98.0, target_final_score_B=100.0)
# Pandas(final_score_A=100.64383697509766, final_score_B=101.24082946777344, target_final_score_A=109.0, target_final_score_B=115.0)
# Pandas(final_score_A=97.45600128173828, final_score_B=95.38641357421875, target_final_score_A=106.0, target_final_score_B=103.0)
# Pandas(final_score_A=107.3998794555664, final_score_B=102.2449951171875, target_final_score_A=106.0, target_final_score_B=95.0)
# Pandas(final_score_A=106.20548248291016, final_score_B=106.2784423828125, target_final_score_A=94.0, target_final_score_B=91.0)
# Pandas(final_score_A=101.50301361083984, final_score_B=96.6339111328125, target_final_score_A=112.0, target_final_score_B=86.0)
# Pandas(final_score_A=93.80928802490234, final_score_B=89.24393463134766, target_final_score_A=110.0, target_final_score_B=72.0)
# Pandas(final_score_A=97.420654296875, final_score_B=93.56782531738281, target_final_score_A=90.0, target_final_score_B=104.0)
# Pandas(final_score_A=111.71977996826172, final_score_B=109.72108459472656, target_final_score_A=123.0, target_final_score_B=92.0)
# Pandas(final_score_A=97.6265640258789, final_score_B=96.53727722167969, target_final_score_A=92.0, target_final_score_B=79.0)
# Pandas(final_score_A=103.97693634033203, final_score_B=101.44842529296875, target_final_score_A=114.0, target_final_score_B=125.0)
# Pandas(final_score_A=95.74724578857422, final_score_B=92.32112121582031, target_final_score_A=111.0, target_final_score_B=119.0)
# Pandas(final_score_A=106.6710433959961, final_score_B=106.56438446044922, target_final_score_A=110.0, target_final_score_B=79.0)
# Pandas(final_score_A=99.50980377197266, final_score_B=98.63025665283203, target_final_score_A=74.0, target_final_score_B=85.0)
# Pandas(final_score_A=110.186767578125, final_score_B=109.9305419921875, target_final_score_A=134.0, target_final_score_B=101.0)
# Pandas(final_score_A=98.36719512939453, final_score_B=98.52392578125, target_final_score_A=85.0, target_final_score_B=100.0)
# Pandas(final_score_A=100.42855072021484, final_score_B=98.06776428222656, target_final_score_A=100.0, target_final_score_B=85.0)
# Pandas(final_score_A=104.56351470947266, final_score_B=104.68791961669922, target_final_score_A=111.0, target_final_score_B=110.0)
# Pandas(final_score_A=110.99688720703125, final_score_B=112.52218627929688, target_final_score_A=115.0, target_final_score_B=99.0)
# Pandas(final_score_A=107.8828125, final_score_B=107.78378295898438, target_final_score_A=90.0, target_final_score_B=123.0)
# Pandas(final_score_A=100.67205810546875, final_score_B=98.15573120117188, target_final_score_A=102.0, target_final_score_B=109.0)
# Pandas(final_score_A=101.71875762939453, final_score_B=100.80775451660156, target_final_score_A=94.0, target_final_score_B=82.0)
# Pandas(final_score_A=99.37991333007812, final_score_B=99.14570617675781, target_final_score_A=92.0, target_final_score_B=102.0)
# Pandas(final_score_A=99.2492904663086, final_score_B=98.40262603759766, target_final_score_A=101.0, target_final_score_B=84.0)
# Pandas(final_score_A=107.67179870605469, final_score_B=100.882568359375, target_final_score_A=103.0, target_final_score_B=91.0)
# Pandas(final_score_A=110.9722900390625, final_score_B=111.01060485839844, target_final_score_A=101.0, target_final_score_B=104.0)
# Pandas(final_score_A=97.13578033447266, final_score_B=94.47254180908203, target_final_score_A=118.0, target_final_score_B=116.0)
# Pandas(final_score_A=104.01193237304688, final_score_B=98.88453674316406, target_final_score_A=112.0, target_final_score_B=77.0)
# Pandas(final_score_A=108.54756927490234, final_score_B=108.08079528808594, target_final_score_A=104.0, target_final_score_B=115.0)
# Pandas(final_score_A=102.00432586669922, final_score_B=102.27671813964844, target_final_score_A=101.0, target_final_score_B=107.0)
# Pandas(final_score_A=106.21014404296875, final_score_B=103.14967346191406, target_final_score_A=102.0, target_final_score_B=95.0)
# Pandas(final_score_A=101.97620391845703, final_score_B=99.15078735351562, target_final_score_A=104.0, target_final_score_B=107.0)
# Pandas(final_score_A=95.74111938476562, final_score_B=91.96255493164062, target_final_score_A=84.0, target_final_score_B=95.0)
# Pandas(final_score_A=97.16279602050781, final_score_B=92.72943115234375, target_final_score_A=90.0, target_final_score_B=83.0)
# Pandas(final_score_A=107.63675689697266, final_score_B=106.8780517578125, target_final_score_A=126.0, target_final_score_B=116.0)
# Pandas(final_score_A=100.2268295288086, final_score_B=100.17742156982422, target_final_score_A=135.0, target_final_score_B=140.0)
# Pandas(final_score_A=103.33871459960938, final_score_B=102.15840148925781, target_final_score_A=106.0, target_final_score_B=99.0)
# Pandas(final_score_A=99.37329864501953, final_score_B=98.61082458496094, target_final_score_A=77.0, target_final_score_B=90.0)
# Pandas(final_score_A=100.51834869384766, final_score_B=100.16738891601562, target_final_score_A=99.0, target_final_score_B=78.0)
# Pandas(final_score_A=101.7781753540039, final_score_B=98.25991821289062, target_final_score_A=98.0, target_final_score_B=88.0)
# Pandas(final_score_A=100.6463623046875, final_score_B=100.8452377319336, target_final_score_A=102.0, target_final_score_B=112.0)
# Pandas(final_score_A=97.13917541503906, final_score_B=93.1483154296875, target_final_score_A=100.0, target_final_score_B=94.0)
# Pandas(final_score_A=95.0910415649414, final_score_B=95.04722595214844, target_final_score_A=110.0, target_final_score_B=102.0)
# Pandas(final_score_A=106.10459899902344, final_score_B=104.11466979980469, target_final_score_A=107.0, target_final_score_B=85.0)
# Pandas(final_score_A=90.84909057617188, final_score_B=88.24835205078125, target_final_score_A=86.0, target_final_score_B=75.0)
# Pandas(final_score_A=101.92709350585938, final_score_B=101.0584487915039, target_final_score_A=121.0, target_final_score_B=114.0)
# Pandas(final_score_A=106.798828125, final_score_B=107.07815551757812, target_final_score_A=94.0, target_final_score_B=87.0)
# Pandas(final_score_A=108.71099853515625, final_score_B=109.01095581054688, target_final_score_A=112.0, target_final_score_B=123.0)
# Pandas(final_score_A=102.10559844970703, final_score_B=99.8124008178711, target_final_score_A=105.0, target_final_score_B=86.0)
# Pandas(final_score_A=105.39495849609375, final_score_B=103.50552368164062, target_final_score_A=122.0, target_final_score_B=123.0)
# Pandas(final_score_A=104.24966430664062, final_score_B=104.93771362304688, target_final_score_A=112.0, target_final_score_B=113.0)
# Pandas(final_score_A=116.9294204711914, final_score_B=114.78358459472656, target_final_score_A=104.0, target_final_score_B=91.0)
# Pandas(final_score_A=94.03697204589844, final_score_B=94.12105560302734, target_final_score_A=93.0, target_final_score_B=97.0)
# Pandas(final_score_A=107.91275787353516, final_score_B=108.18760681152344, target_final_score_A=120.0, target_final_score_B=115.0)
# Pandas(final_score_A=95.36905670166016, final_score_B=91.30094909667969, target_final_score_A=99.0, target_final_score_B=77.0)
# Pandas(final_score_A=88.37456512451172, final_score_B=87.25090026855469, target_final_score_A=87.0, target_final_score_B=73.0)
# Pandas(final_score_A=112.4614486694336, final_score_B=110.05305480957031, target_final_score_A=122.0, target_final_score_B=117.0)
# Pandas(final_score_A=104.31989288330078, final_score_B=98.60133361816406, target_final_score_A=119.0, target_final_score_B=74.0)
# Pandas(final_score_A=104.767333984375, final_score_B=99.47273254394531, target_final_score_A=99.0, target_final_score_B=103.0)
# Pandas(final_score_A=100.36044311523438, final_score_B=100.55868530273438, target_final_score_A=92.0, target_final_score_B=78.0)
# Pandas(final_score_A=94.73075103759766, final_score_B=92.25984191894531, target_final_score_A=85.0, target_final_score_B=80.0)
# Pandas(final_score_A=101.14375305175781, final_score_B=100.77972412109375, target_final_score_A=86.0, target_final_score_B=115.0)
# Pandas(final_score_A=99.32215881347656, final_score_B=100.32792663574219, target_final_score_A=127.0, target_final_score_B=114.0)
# Pandas(final_score_A=99.45903015136719, final_score_B=95.871826171875, target_final_score_A=112.0, target_final_score_B=114.0)
# Pandas(final_score_A=122.45945739746094, final_score_B=116.25967407226562, target_final_score_A=109.0, target_final_score_B=117.0)
# Pandas(final_score_A=113.95874786376953, final_score_B=113.99954986572266, target_final_score_A=90.0, target_final_score_B=64.0)
# Pandas(final_score_A=100.19384765625, final_score_B=100.07252502441406, target_final_score_A=94.0, target_final_score_B=99.0)
# Pandas(final_score_A=110.97039031982422, final_score_B=111.06350708007812, target_final_score_A=125.0, target_final_score_B=86.0)
# ...
# Pandas(final_score_A=99.10376739501953, final_score_B=98.37158203125, target_final_score_A=103.0, target_final_score_B=87.0)
# Pandas(final_score_A=106.4337387084961, final_score_B=103.67469787597656, target_final_score_A=143.0, target_final_score_B=146.0)
# Pandas(final_score_A=108.78543853759766, final_score_B=109.68167114257812, target_final_score_A=119.0, target_final_score_B=111.0)
# Pandas(final_score_A=102.48106384277344, final_score_B=98.1671371459961, target_final_score_A=96.0, target_final_score_B=86.0)
# Pandas(final_score_A=108.75048828125, final_score_B=105.71342468261719, target_final_score_A=124.0, target_final_score_B=104.0)
# Pandas(final_score_A=113.15911102294922, final_score_B=108.09304809570312, target_final_score_A=106.0, target_final_score_B=134.0)
# Pandas(final_score_A=108.13324737548828, final_score_B=108.58953857421875, target_final_score_A=113.0, target_final_score_B=118.0)
# Pandas(final_score_A=100.95011138916016, final_score_B=97.99252319335938, target_final_score_A=90.0, target_final_score_B=97.0)
# Pandas(final_score_A=106.2820816040039, final_score_B=103.76460266113281, target_final_score_A=106.0, target_final_score_B=109.0)
# Pandas(final_score_A=98.13325500488281, final_score_B=95.93994140625, target_final_score_A=127.0, target_final_score_B=98.0)
# Pandas(final_score_A=101.14855194091797, final_score_B=99.95086669921875, target_final_score_A=106.0, target_final_score_B=112.0)
# Pandas(final_score_A=107.46067810058594, final_score_B=103.86485290527344, target_final_score_A=117.0, target_final_score_B=119.0)
# Pandas(final_score_A=96.39816284179688, final_score_B=94.04878234863281, target_final_score_A=99.0, target_final_score_B=86.0)
# Pandas(final_score_A=95.69261932373047, final_score_B=91.56151580810547, target_final_score_A=103.0, target_final_score_B=100.0)
# Pandas(final_score_A=110.85084533691406, final_score_B=110.57852172851562, target_final_score_A=118.0, target_final_score_B=101.0)
# Pandas(final_score_A=111.46134185791016, final_score_B=112.58082580566406, target_final_score_A=121.0, target_final_score_B=106.0)
# Pandas(final_score_A=113.47384643554688, final_score_B=114.19500732421875, target_final_score_A=126.0, target_final_score_B=108.0)
# Pandas(final_score_A=107.61408233642578, final_score_B=107.16773223876953, target_final_score_A=115.0, target_final_score_B=119.0)
# Pandas(final_score_A=103.3903579711914, final_score_B=98.5029296875, target_final_score_A=125.0, target_final_score_B=132.0)
# Pandas(final_score_A=111.56681060791016, final_score_B=112.31965637207031, target_final_score_A=107.0, target_final_score_B=101.0)
# Pandas(final_score_A=97.2403564453125, final_score_B=94.09970092773438, target_final_score_A=87.0, target_final_score_B=103.0)
# Pandas(final_score_A=102.4354019165039, final_score_B=102.26444244384766, target_final_score_A=98.0, target_final_score_B=111.0)
# Pandas(final_score_A=95.11087036132812, final_score_B=90.13085174560547, target_final_score_A=98.0, target_final_score_B=103.0)
# Pandas(final_score_A=105.77271270751953, final_score_B=103.86770629882812, target_final_score_A=101.0, target_final_score_B=93.0)
# Pandas(final_score_A=103.19242095947266, final_score_B=101.75028991699219, target_final_score_A=118.0, target_final_score_B=90.0)
# Pandas(final_score_A=99.39820861816406, final_score_B=94.71672058105469, target_final_score_A=88.0, target_final_score_B=95.0)
# Pandas(final_score_A=117.7109146118164, final_score_B=118.69172668457031, target_final_score_A=124.0, target_final_score_B=120.0)
# Pandas(final_score_A=100.70525360107422, final_score_B=100.93852233886719, target_final_score_A=91.0, target_final_score_B=97.0)
# Pandas(final_score_A=102.78617095947266, final_score_B=100.72201538085938, target_final_score_A=121.0, target_final_score_B=94.0)
# Pandas(final_score_A=108.01705169677734, final_score_B=107.0315170288086, target_final_score_A=97.0, target_final_score_B=94.0)
# Pandas(final_score_A=100.6715316772461, final_score_B=99.29684448242188, target_final_score_A=102.0, target_final_score_B=99.0)
# Pandas(final_score_A=111.66763305664062, final_score_B=111.39381408691406, target_final_score_A=123.0, target_final_score_B=102.0)
# Pandas(final_score_A=99.31768798828125, final_score_B=99.07832336425781, target_final_score_A=98.0, target_final_score_B=94.0)
# Pandas(final_score_A=99.14057159423828, final_score_B=98.75945281982422, target_final_score_A=93.0, target_final_score_B=91.0)
# Pandas(final_score_A=104.49027252197266, final_score_B=103.73431396484375, target_final_score_A=100.0, target_final_score_B=93.0)
# Pandas(final_score_A=106.92998504638672, final_score_B=106.28732299804688, target_final_score_A=80.0, target_final_score_B=89.0)
# Pandas(final_score_A=108.682373046875, final_score_B=109.39091491699219, target_final_score_A=112.0, target_final_score_B=85.0)
# Pandas(final_score_A=96.02548217773438, final_score_B=92.35366821289062, target_final_score_A=97.0, target_final_score_B=79.0)
# Pandas(final_score_A=108.28417205810547, final_score_B=106.78485107421875, target_final_score_A=93.0, target_final_score_B=108.0)
# Pandas(final_score_A=104.1127700805664, final_score_B=98.76618194580078, target_final_score_A=120.0, target_final_score_B=107.0)
# Pandas(final_score_A=107.136474609375, final_score_B=106.03592681884766, target_final_score_A=117.0, target_final_score_B=103.0)
# Pandas(final_score_A=106.301025390625, final_score_B=101.03865051269531, target_final_score_A=133.0, target_final_score_B=113.0)
# Pandas(final_score_A=96.29609680175781, final_score_B=91.2305908203125, target_final_score_A=99.0, target_final_score_B=93.0)
# Pandas(final_score_A=106.10792541503906, final_score_B=105.46501159667969, target_final_score_A=110.0, target_final_score_B=107.0)
# Pandas(final_score_A=104.79674530029297, final_score_B=100.86216735839844, target_final_score_A=103.0, target_final_score_B=98.0)
# Pandas(final_score_A=97.26078033447266, final_score_B=95.3818359375, target_final_score_A=83.0, target_final_score_B=95.0)
# Pandas(final_score_A=107.40831756591797, final_score_B=109.09992980957031, target_final_score_A=103.0, target_final_score_B=116.0)
# Pandas(final_score_A=99.71489715576172, final_score_B=98.1448974609375, target_final_score_A=91.0, target_final_score_B=96.0)
# Pandas(final_score_A=113.4950942993164, final_score_B=113.14797973632812, target_final_score_A=107.0, target_final_score_B=103.0)
# Pandas(final_score_A=100.50658416748047, final_score_B=96.53645324707031, target_final_score_A=103.0, target_final_score_B=90.0)
# Pandas(final_score_A=99.1799545288086, final_score_B=95.56507873535156, target_final_score_A=106.0, target_final_score_B=98.0)
# Pandas(final_score_A=98.3773422241211, final_score_B=98.68236541748047, target_final_score_A=106.0, target_final_score_B=96.0)
# Pandas(final_score_A=109.7308349609375, final_score_B=110.2098159790039, target_final_score_A=96.0, target_final_score_B=120.0)
# Pandas(final_score_A=103.22107696533203, final_score_B=102.46994018554688, target_final_score_A=120.0, target_final_score_B=129.0)
# Pandas(final_score_A=97.14859771728516, final_score_B=96.48041534423828, target_final_score_A=86.0, target_final_score_B=94.0)
# Pandas(final_score_A=100.36343383789062, final_score_B=100.21890258789062, target_final_score_A=93.0, target_final_score_B=90.0)
# Pandas(final_score_A=99.0627670288086, final_score_B=98.19418334960938, target_final_score_A=89.0, target_final_score_B=92.0)
# Pandas(final_score_A=99.37822723388672, final_score_B=96.55377960205078, target_final_score_A=73.0, target_final_score_B=99.0)
# Pandas(final_score_A=102.0857925415039, final_score_B=101.38114929199219, target_final_score_A=112.0, target_final_score_B=103.0)
# Pandas(final_score_A=91.9625473022461, final_score_B=88.37174987792969, target_final_score_A=85.0, target_final_score_B=83.0)
# Pandas(final_score_A=104.3333969116211, final_score_B=105.29299926757812, target_final_score_A=112.0, target_final_score_B=90.0)
# Pandas(final_score_A=93.74958038330078, final_score_B=89.89852142333984, target_final_score_A=96.0, target_final_score_B=86.0)
# Pandas(final_score_A=94.74003601074219, final_score_B=91.21627044677734, target_final_score_A=99.0, target_final_score_B=106.0)
# Pandas(final_score_A=105.60240173339844, final_score_B=102.22917175292969, target_final_score_A=123.0, target_final_score_B=104.0)
# Pandas(final_score_A=100.45365142822266, final_score_B=95.50105285644531, target_final_score_A=102.0, target_final_score_B=78.0)
# Pandas(final_score_A=103.07462310791016, final_score_B=98.40013122558594, target_final_score_A=89.0, target_final_score_B=100.0)
# Pandas(final_score_A=104.01634216308594, final_score_B=104.36839294433594, target_final_score_A=128.0, target_final_score_B=119.0)
# Pandas(final_score_A=103.02765655517578, final_score_B=103.35250854492188, target_final_score_A=104.0, target_final_score_B=105.0)
# Pandas(final_score_A=112.0270767211914, final_score_B=111.11473083496094, target_final_score_A=102.0, target_final_score_B=104.0)
# Pandas(final_score_A=111.76480102539062, final_score_B=111.45915222167969, target_final_score_A=102.0, target_final_score_B=95.0)
# Pandas(final_score_A=108.87682342529297, final_score_B=109.30018615722656, target_final_score_A=99.0, target_final_score_B=128.0)
# Pandas(final_score_A=110.21234893798828, final_score_B=110.43370056152344, target_final_score_A=120.0, target_final_score_B=109.0)
# Pandas(final_score_A=98.9718246459961, final_score_B=95.85977935791016, target_final_score_A=94.0, target_final_score_B=86.0)
# Pandas(final_score_A=97.70191955566406, final_score_B=94.53263854980469, target_final_score_A=92.0, target_final_score_B=100.0)
# Pandas(final_score_A=105.94913482666016, final_score_B=101.82818603515625, target_final_score_A=141.0, target_final_score_B=146.0)
# Pandas(final_score_A=107.99736022949219, final_score_B=107.6783676147461, target_final_score_A=116.0, target_final_score_B=109.0)
# Pandas(final_score_A=94.94984436035156, final_score_B=89.79166412353516, target_final_score_A=99.0, target_final_score_B=89.0)
# Pandas(final_score_A=100.76002502441406, final_score_B=100.69496154785156, target_final_score_A=104.0, target_final_score_B=95.0)
# Pandas(final_score_A=104.93627166748047, final_score_B=104.53873443603516, target_final_score_A=134.0, target_final_score_B=122.0)
# Pandas(final_score_A=96.39584350585938, final_score_B=91.56919860839844, target_final_score_A=84.0, target_final_score_B=91.0)
# Pandas(final_score_A=108.84420776367188, final_score_B=110.52290344238281, target_final_score_A=86.0, target_final_score_B=103.0)
# Pandas(final_score_A=100.53311920166016, final_score_B=101.48724365234375, target_final_score_A=103.0, target_final_score_B=124.0)
# Pandas(final_score_A=110.36912536621094, final_score_B=110.30870056152344, target_final_score_A=116.0, target_final_score_B=117.0)
# Pandas(final_score_A=104.26932525634766, final_score_B=103.63204956054688, target_final_score_A=100.0, target_final_score_B=109.0)
# Pandas(final_score_A=110.05760955810547, final_score_B=109.64469909667969, target_final_score_A=133.0, target_final_score_B=115.0)
# Pandas(final_score_A=101.85681915283203, final_score_B=101.06840515136719, target_final_score_A=91.0, target_final_score_B=83.0)
# Pandas(final_score_A=105.84017181396484, final_score_B=102.8870849609375, target_final_score_A=115.0, target_final_score_B=90.0)
# Pandas(final_score_A=111.32135772705078, final_score_B=112.60212707519531, target_final_score_A=86.0, target_final_score_B=102.0)
# Pandas(final_score_A=100.20833587646484, final_score_B=99.9317626953125, target_final_score_A=113.0, target_final_score_B=87.0)
# Pandas(final_score_A=104.17986297607422, final_score_B=103.92780303955078, target_final_score_A=111.0, target_final_score_B=124.0)
# Pandas(final_score_A=100.56088256835938, final_score_B=100.64863586425781, target_final_score_A=107.0, target_final_score_B=88.0)
# Pandas(final_score_A=108.20105743408203, final_score_B=109.15885162353516, target_final_score_A=122.0, target_final_score_B=116.0)
# Pandas(final_score_A=106.00471496582031, final_score_B=105.41724395751953, target_final_score_A=103.0, target_final_score_B=121.0)
# Pandas(final_score_A=104.03076171875, final_score_B=100.21733856201172, target_final_score_A=102.0, target_final_score_B=87.0)
# Pandas(final_score_A=104.8294906616211, final_score_B=99.77664184570312, target_final_score_A=116.0, target_final_score_B=92.0)
# Pandas(final_score_A=99.0052261352539, final_score_B=99.08694458007812, target_final_score_A=109.0, target_final_score_B=74.0)
# Pandas(final_score_A=99.93892669677734, final_score_B=96.06114196777344, target_final_score_A=83.0, target_final_score_B=93.0)
# Pandas(final_score_A=98.7039566040039, final_score_B=96.71743774414062, target_final_score_A=82.0, target_final_score_B=74.0)
# Pandas(final_score_A=95.44241333007812, final_score_B=95.36695861816406, target_final_score_A=92.0, target_final_score_B=84.0)
# Pandas(final_score_A=106.57328033447266, final_score_B=106.79994201660156, target_final_score_A=94.0, target_final_score_B=112.0)
# Pandas(final_score_A=100.30452728271484, final_score_B=98.23191833496094, target_final_score_A=92.0, target_final_score_B=91.0)
# Pandas(final_score_A=101.4217758178711, final_score_B=99.95974731445312, target_final_score_A=106.0, target_final_score_B=104.0)
# Pandas(final_score_A=100.40808868408203, final_score_B=98.94539642333984, target_final_score_A=91.0, target_final_score_B=82.0)
# Pandas(final_score_A=108.96856689453125, final_score_B=103.12986755371094, target_final_score_A=126.0, target_final_score_B=127.0)
# Pandas(final_score_A=110.43375396728516, final_score_B=112.28785705566406, target_final_score_A=120.0, target_final_score_B=134.0)
# Pandas(final_score_A=101.43463897705078, final_score_B=99.36920166015625, target_final_score_A=89.0, target_final_score_B=85.0)
# Pandas(final_score_A=101.37468719482422, final_score_B=96.65751647949219, target_final_score_A=114.0, target_final_score_B=98.0)
# Pandas(final_score_A=112.19657135009766, final_score_B=110.87834930419922, target_final_score_A=109.0, target_final_score_B=118.0)
# Pandas(final_score_A=109.27703094482422, final_score_B=109.93281555175781, target_final_score_A=98.0, target_final_score_B=107.0)
# Pandas(final_score_A=96.74401092529297, final_score_B=96.1937255859375, target_final_score_A=99.0, target_final_score_B=100.0)
# Pandas(final_score_A=98.0155029296875, final_score_B=93.134033203125, target_final_score_A=110.0, target_final_score_B=99.0)
# Pandas(final_score_A=96.2208023071289, final_score_B=93.7769775390625, target_final_score_A=95.0, target_final_score_B=91.0)
# Pandas(final_score_A=102.91011810302734, final_score_B=103.90557861328125, target_final_score_A=94.0, target_final_score_B=104.0)
# Pandas(final_score_A=111.18390655517578, final_score_B=107.509033203125, target_final_score_A=111.0, target_final_score_B=102.0)
# Pandas(final_score_A=103.59127044677734, final_score_B=100.53836059570312, target_final_score_A=127.0, target_final_score_B=107.0)
# Pandas(final_score_A=101.81658935546875, final_score_B=95.81069946289062, target_final_score_A=103.0, target_final_score_B=82.0)
# Pandas(final_score_A=106.2735824584961, final_score_B=106.79824829101562, target_final_score_A=111.0, target_final_score_B=104.0)
# Pandas(final_score_A=106.3810043334961, final_score_B=104.7701644897461, target_final_score_A=104.0, target_final_score_B=122.0)
# Pandas(final_score_A=109.49230194091797, final_score_B=110.32579803466797, target_final_score_A=109.0, target_final_score_B=120.0)
# Pandas(final_score_A=100.33187866210938, final_score_B=100.26305389404297, target_final_score_A=101.0, target_final_score_B=96.0)
# Pandas(final_score_A=102.9723129272461, final_score_B=100.08619689941406, target_final_score_A=121.0, target_final_score_B=109.0)
# Pandas(final_score_A=101.35218048095703, final_score_B=101.24048614501953, target_final_score_A=110.0, target_final_score_B=112.0)
# Pandas(final_score_A=88.87933349609375, final_score_B=83.25077819824219, target_final_score_A=71.0, target_final_score_B=81.0)
# Pandas(final_score_A=98.90729522705078, final_score_B=93.05957794189453, target_final_score_A=116.0, target_final_score_B=95.0)

# %%
y_pred = predictions[0].drop(columns = ["target_final_score_A", "target_final_score_B"])
y_label = predictions[0].drop(columns = ["final_score_A", "final_score_B"])

# %%
from sklearn.metrics import f1_score
f1_score(y_pred, y_label)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 from sklearn.metrics import f1_score
# ----> 2 f1_score(y_pred, y_label)
#
# File ~/Documents/GitHub/sports-betting/sports-betting/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/Documents/GitHub/sports-betting/sports-betting/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1239, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1070 @validate_params(
#    1071     {
#    1072         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1097     zero_division="warn",
#    1098 ):
#    1099     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1100
#    1101     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1237     array([0.66666667, 1.        , 0.66666667])
#    1238     """
# -> 1239     return fbeta_score(
#    1240         y_true,
#    1241         y_pred,
#    1242         beta=1,
#    1243         labels=labels,
#    1244         pos_label=pos_label,
#    1245         average=average,
#    1246         sample_weight=sample_weight,
#    1247         zero_division=zero_division,
#    1248     )
#
# File ~/Documents/GitHub/sports-betting/sports-betting/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/Documents/GitHub/sports-betting/sports-betting/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1413, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1251 @validate_params(
#    1252     {
#    1253         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1280     zero_division="warn",
#    1281 ):
#    1282     """Compute the F-beta score.
#    1283
#    1284     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1410     0.38...
#    1411     """
# -> 1413     _, _, f, _ = precision_recall_fscore_support(
#    1414         y_true,
#    1415         y_pred,
#    1416         beta=beta,
#    1417         labels=labels,
#    1418         pos_label=pos_label,
#    1419         average=average,
#    1420         warn_for=("f-score",),
#    1421         sample_weight=sample_weight,
#    1422         zero_division=zero_division,
#    1423     )
#    1424     return f
#
# File ~/Documents/GitHub/sports-betting/sports-betting/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/Documents/GitHub/sports-betting/sports-betting/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1724, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1566 """Compute precision, recall, F-measure and support for each class.
#    1567
#    1568 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1721  array([2, 2, 2]))
#    1722 """
#    1723 zero_division_value = _check_zero_division(zero_division)
# -> 1724 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1726 # Calculate tp_sum, pred_sum, true_sum ###
#    1727 samplewise = average == "samples"
#
# File ~/Documents/GitHub/sports-betting/sports-betting/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1501, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1498 if average not in average_options and average != "binary":
#    1499     raise ValueError("average has to be one of " + str(average_options))
# -> 1501 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1502 # Convert to Python primitive type to avoid NumPy type / Python str
#    1503 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1504 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File ~/Documents/GitHub/sports-betting/sports-betting/lib/python3.8/site-packages/sklearn/metrics/_classification.py:93, in _check_targets(y_true, y_pred)
#      90     y_type = {"multiclass"}
#      92 if len(y_type) > 1:
# ---> 93     raise ValueError(
#      94         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95             type_true, type_pred
#      96         )
#      97     )
#      99 # We can't have more than one value on y_type => The set is no more needed
#     100 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of continuous-multioutput and multiclass-multioutput targets

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
predictions[0].hist(bins=75, figsize=(20,15))
plt.show()
