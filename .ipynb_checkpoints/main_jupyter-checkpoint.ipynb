# %%
# !pip install -r requirements.txt
# Out:
# Collecting absl-py==2.1.0
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 1.7 MB/s eta 0:00:01
# Collecting astunparse==1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting black==24.8.0
#   Downloading black-24.8.0-cp38-cp38-macosx_10_9_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.4 MB/s eta 0:00:01
# Collecting cachetools==5.5.0
#   Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Collecting certifi==2024.8.30
#   Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#      |████████████████████████████████| 167 kB 3.1 MB/s eta 0:00:01
# Collecting charset-normalizer==3.4.0
#   Downloading charset_normalizer-3.4.0-cp38-cp38-macosx_10_9_x86_64.whl (124 kB)
#      |████████████████████████████████| 124 kB 8.0 MB/s eta 0:00:01
# Collecting click==8.1.7
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 12.8 MB/s eta 0:00:01
# Collecting exceptiongroup==1.2.1
#   Downloading exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Collecting filelock==3.15.4
#   Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Collecting flatbuffers==24.3.25
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting fsspec==2024.6.1
#   Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      |████████████████████████████████| 177 kB 8.1 MB/s eta 0:00:01
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting google-auth==2.35.0
#   Downloading google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 9.4 MB/s eta 0:00:01
# Collecting google-auth-oauthlib==1.0.0
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting google-pasta==0.2.0
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting grpcio==1.67.0
#   Downloading grpcio-1.67.0.tar.gz (12.6 MB)
#      |████████████████████████████████| 12.6 MB 15.0 MB/s eta 0:00:01
# Collecting h5py==3.11.0
#   Downloading h5py-3.11.0-cp38-cp38-macosx_10_9_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 24.0 MB/s eta 0:00:01
# Collecting idna==3.10
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 19.3 MB/s eta 0:00:01
# Collecting importlib_metadata==8.5.0
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Collecting iniconfig==2.0.0
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting Jinja2==3.1.4
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 12.7 MB/s eta 0:00:01
# Collecting keras==2.13.1
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 5.6 MB/s eta 0:00:01
# Collecting libclang==18.1.1
#   Downloading libclang-18.1.1-py2.py3-none-macosx_10_9_x86_64.whl (26.5 MB)
#      |████████████████████████████████| 26.5 MB 1.7 MB/s eta 0:00:01
# Collecting lxml==5.3.0
#   Downloading lxml-5.3.0-cp38-cp38-macosx_10_9_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 5.1 MB/s eta 0:00:01
# Collecting Markdown==3.7
#   Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 6.7 MB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe==2.1.5 in /Users/joaquinuriarte/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (2.1.5)
# Collecting mpmath==1.3.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      |████████████████████████████████| 536 kB 31.8 MB/s eta 0:00:01
# Collecting mypy==1.13.0
#   Downloading mypy-1.13.0-cp38-cp38-macosx_10_9_x86_64.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 1.6 MB/s eta 0:00:01
# Collecting mypy-extensions==1.0.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting networkx==3.1
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 6.0 MB/s eta 0:00:01
# Collecting numpy==1.24.4
#   Downloading numpy-1.24.4-cp38-cp38-macosx_10_9_x86_64.whl (19.8 MB)
#      |████████████████████████████████| 19.8 MB 1.1 MB/s eta 0:00:01
# Collecting oauthlib==3.2.2
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 3.7 MB/s eta 0:00:01
# Collecting opt_einsum==3.4.0
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 1.2 MB/s eta 0:00:011
# Collecting packaging==24.0
#   Downloading packaging-24.0-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 3.5 MB/s eta 0:00:011
# Collecting pandas==2.0.3
#   Downloading pandas-2.0.3-cp38-cp38-macosx_10_9_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 2.7 MB/s eta 0:00:01
# Collecting pandas-stubs==2.0.3.230814
#   Downloading pandas_stubs-2.0.3.230814-py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 4.4 MB/s eta 0:00:01
# Collecting pathspec==0.12.1
#   Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: platformdirs==4.2.0 in /Users/joaquinuriarte/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (4.2.0)
# Collecting pluggy==1.5.0
#   Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Collecting protobuf==4.25.5
#   Downloading protobuf-4.25.5-py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 5.0 MB/s eta 0:00:01
# Collecting pyasn1==0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 3.6 MB/s eta 0:00:01
# Collecting pyasn1_modules==0.4.1
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 6.2 MB/s eta 0:00:01
# Collecting pytest==8.1.1
#   Downloading pytest-8.1.1-py3-none-any.whl (337 kB)
#      |████████████████████████████████| 337 kB 4.9 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /Users/joaquinuriarte/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (2.9.0.post0)
# Collecting pytz==2024.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      |████████████████████████████████| 505 kB 4.7 MB/s eta 0:00:01
# Collecting PyYAML==6.0.1
#   Downloading PyYAML-6.0.1-cp38-cp38-macosx_10_9_x86_64.whl (191 kB)
#      |████████████████████████████████| 191 kB 6.0 MB/s eta 0:00:01
# Collecting requests==2.32.3
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 8.3 MB/s  eta 0:00:01
# Collecting requests-oauthlib==2.0.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting rsa==4.9
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting six==1.16.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting sympy==1.13.2
#   Downloading sympy-1.13.2-py3-none-any.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 3.7 MB/s eta 0:00:01
# Collecting tensorboard==2.13.0
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 4.0 MB/s eta 0:00:01
# Collecting tensorboard-data-server==0.7.2
#   Downloading tensorboard_data_server-0.7.2-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 4.0 MB/s eta 0:00:01
# Collecting tensorflow==2.13.1
#   Downloading tensorflow-2.13.1-cp38-cp38-macosx_10_15_x86_64.whl (216.2 MB)
#      |████████████████████████████████| 216.2 MB 12 kB/s  eta 0:00:01     |███████████████▊                | 106.3 MB 3.4 MB/s eta 0:00:33
# Collecting tensorflow-estimator==2.13.0
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#      |████████████████████████████████| 440 kB 1.7 MB/s eta 0:00:01
# Collecting tensorflow-io-gcs-filesystem==0.34.0
#   Downloading tensorflow_io_gcs_filesystem-0.34.0-cp38-cp38-macosx_10_14_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 2.8 MB/s eta 0:00:01
# Collecting termcolor==2.4.0
#   Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: tomli==2.0.1 in /Users/joaquinuriarte/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 58)) (2.0.1)
# Collecting torch==2.2.2
#   Downloading torch-2.2.2-cp38-none-macosx_10_9_x86_64.whl (150.6 MB)
#      |████████████████████████████████| 150.6 MB 5.2 MB/s eta 0:00:01
# Collecting types-pytz==2024.2.0.20241003
#   Downloading types_pytz-2024.2.0.20241003-py3-none-any.whl (5.2 kB)
# Collecting types-PyYAML==6.0.12.20240917
#   Downloading types_PyYAML-6.0.12.20240917-py3-none-any.whl (15 kB)
# Collecting typing_extensions==4.12.2
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting tzdata==2024.1
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      |████████████████████████████████| 345 kB 5.9 MB/s eta 0:00:01
# Collecting urllib3==2.2.3
#   Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 6.3 MB/s eta 0:00:01
# Collecting Werkzeug==3.0.4
#   Downloading werkzeug-3.0.4-py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 5.4 MB/s eta 0:00:01
# Collecting wrapt==1.16.0
#   Downloading wrapt-1.16.0-cp38-cp38-macosx_10_9_x86_64.whl (37 kB)
# Collecting zipp==3.20.2
#   Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/joaquinuriarte/opt/anaconda3/lib/python3.8/site-packages (from astunparse==1.6.3->-r requirements.txt (line 2)) (0.34.2)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/joaquinuriarte/opt/anaconda3/lib/python3.8/site-packages (from tensorboard==2.13.0->-r requirements.txt (line 52)) (49.2.0.post20200714)
# Building wheels for collected packages: grpcio
#   Building wheel for grpcio (setup.py) ... |

# %%
# Main file
# Use case: Pilot test, "integration test"

# === STEP 0: Imports
print("# === STEP 0: Imports: Starting ...")
from modules.dataset_generator.helpers.configuration_loader import ConfigurationLoader as DSConfigLoader
from modules.dataset_generator.factories.data_io_factory import DataIOFactory
from modules.dataset_generator.factories.feature_processor_factory import FeatureProcessorFactory
from modules.dataset_generator.factories.join_factory import JoinFactory
from modules.dataset_generator.factories.strategy_factory import StrategyFactory
from modules.dataset_generator.dataset_generator import DatasetGenerator
from modules.processor.helpers.configuration_loader import ConfigurationLoader as PConfigLoader
from modules.processor.factories.split_strategy_factory import SplitStrategyFactory
from modules.processor.processor import Processor
from modules.model_manager.trainer.trainer import Trainer
from modules.model_manager.predictor.predictor import Predictor
from modules.model_manager.factories.model_factory import ModelFactory
from modules.model_manager.helpers.configuration_loader import ConfigurationLoader as MMConfigLoader
from modules.model_manager.model_manager import ModelManager
print("# === STEP 0: Imports: Complete")
# Out:
# # === STEP 0: Imports: Starting ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a41dba454a64> in <module>
#      15 from modules.model_manager.trainer.trainer import Trainer
#      16 from modules.model_manager.predictor.predictor import Predictor
# ---> 17 from modules.model_manager.factories.model_factory import ModelFactory
#      18 from modules.model_manager.helpers.configuration_loader import ConfigurationLoader as MMConfigLoader
#      19 from modules.model_manager.model_manager import ModelManager
#
# ~/Documents/GitHub/sports-betting/modules/model_manager/factories/model_factory.py in <module>
#       1 from modules.interfaces.factory_interface import IFactory
#       2 from modules.model_manager.interfaces.model_interface import IModel
# ----> 3 from modules.model_manager.implementations.tensorflow_model import TensorFlowModel
#       4 from typing import Any
#       5
#
# ~/Documents/GitHub/sports-betting/modules/model_manager/implementations/tensorflow_model.py in <module>
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#       3 import pandas as pd
#       4 from typing import List
#       5 from modules.model_manager.interfaces.model_interface import IModel
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# === STEP 1: Dependency Instantiations And Global Variable Declarations
print("# === STEP 1: Dependency Instantiations And Global Variable Declarations: Starting ...")
## === DATASET GEN
yaml_path = '/Users/joaquinuriarte/Documents/GitHub/sports-betting/configs/model_v0.yaml'
ds_configuration_loader = DSConfigLoader()
data_factory, feature_processor_factory, join_factory, strategy_factory = DataIOFactory(), FeatureProcessorFactory(), JoinFactory(), StrategyFactory()
## === PROCESSOR
p_configuration_loader = PConfigLoader()
split_strategy_factory = SplitStrategyFactory()
## === MODEL MANAGER
trainer = Trainer()
predictor = Predictor()
model_factory = ModelFactory()
mm_configuration_loader = MMConfigLoader()
print("# === STEP 1: Dependency Instantiations And Global Variable Declarations: Complete")

# %%
# === STEP 2: DATASET GEN
print("# === STEP 2: DATASET GEN: Starting ...")
dataset_generator = DatasetGenerator(yaml_path, ds_configuration_loader, data_factory, feature_processor_factory, join_factory, strategy_factory)

# %%
processed_dataset = dataset_generator.generate()
print("# === STEP 2: DATASET GEN: Complete")

# %%
# === STEP 3: PROCESSOR
print("# === STEP 3: PROCESSOR: Starting ...")
processor = Processor(yaml_path, p_configuration_loader, processed_dataset, split_strategy_factory)

# %%
train_dataset, validation_dataset = processor.generate(val_dataset_flag=True)
print("# === STEP 3: PROCESSOR: Complete")

# %%
# === STEP 4: MODEL MANAGER
print("# === STEP 4: MODEL MANAGER: Starting ...")
model_manager = ModelManager(trainer, predictor, model_factory, mm_configuration_loader)

# %%
models_and_config = model_manager.create_models([yaml_path]) # No use for the ModelConfig, could spare returning it

# %%
for item in models_and_config:
    model_manager.train([item[0]], [tuple(train_dataset, validation_dataset)], save_after_training=True)
    # train needs to return the validation prediction. Otherwise we can call predict on validation as shown below
    validation_predictions = model_manager.predict([item[0]], [validation_dataset.examples])
    print(f"Validation_predictions: {validation_predictions}")
    print(f"Validation_dataset: {validation_dataset}")
print("# === STEP 4: MODEL MANAGER: Complete")
